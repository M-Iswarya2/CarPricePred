# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Iswarya2/CarPricePred/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("nehalbirla/vehicle-dataset-from-cardekho")
# Out:
# Using Colab cache for faster access to the 'vehicle-dataset-from-cardekho' dataset.

# %%
import os
import pandas as pd
df = pd.read_csv(os.path.join(path, "car data.csv"))

# %%
import numpy
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
print(df[:5])
print(df.shape)
print(df.columns)
# Out:
#   Car_Name  Year  Selling_Price  ...  Seller_Type  Transmission Owner
# 0     ritz  2014           3.35  ...       Dealer        Manual     0
# 1      sx4  2013           4.75  ...       Dealer        Manual     0
# 2     ciaz  2017           7.25  ...       Dealer        Manual     0
# 3  wagon r  2011           2.85  ...       Dealer        Manual     0
# 4    swift  2014           4.60  ...       Dealer        Manual     0
#
# [5 rows x 9 columns]
# (301, 9)
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    147
# Kms_Driven       206
# Fuel_Type          3
# Seller_Type        2
# Transmission       2
# Owner              3
# dtype: int64

# %%
df.drop("Car_Name",axis=1)
# Out:
#      Year  Selling_Price  Present_Price  ...  Seller_Type Transmission Owner
# 0    2014           3.35           5.59  ...       Dealer       Manual     0
# 1    2013           4.75           9.54  ...       Dealer       Manual     0
# 2    2017           7.25           9.85  ...       Dealer       Manual     0
# 3    2011           2.85           4.15  ...       Dealer       Manual     0
# 4    2014           4.60           6.87  ...       Dealer       Manual     0
# ..    ...            ...            ...  ...          ...          ...   ...
# 296  2016           9.50          11.60  ...       Dealer       Manual     0
# 297  2015           4.00           5.90  ...       Dealer       Manual     0
# 298  2009           3.35          11.00  ...       Dealer       Manual     0
# 299  2017          11.50          12.50  ...       Dealer       Manual     0
# 300  2016           5.30           5.90  ...       Dealer       Manual     0
#
# [301 rows x 8 columns]

# %%
df = pd.get_dummies(df, columns=["Fuel_Type"], drop_first=False)
df=pd.get_dummies(df,columns=["Seller_Type","Transmission"],drop_first=True)
#one hot encoding kind of... and all these columns has only 2 values ... so drop_first does if n cols are there ...makes n-1 columns...

# %%
print(df[:5])
print(df.columns)
# Out:
#   Car_Name  Year  ...  Seller_Type_Individual  Transmission_Manual
# 0     ritz  2014  ...                   False                 True
# 1      sx4  2013  ...                   False                 True
# 2     ciaz  2017  ...                   False                 True
# 3  wagon r  2011  ...                   False                 True
# 4    swift  2014  ...                   False                 True
#
# [5 rows x 11 columns]
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Owner', 'Fuel_Type_CNG', 'Fuel_Type_Diesel', 'Fuel_Type_Petrol',
#        'Seller_Type_Individual', 'Transmission_Manual'],
#       dtype='object')

# %%
df.drop("Car_Name",axis=1,inplace=True)

# %%
df.dtypes
# Out:
# Year                        int64
# Selling_Price             float64
# Present_Price             float64
# Kms_Driven                  int64
# Owner                       int64
# Fuel_Type_CNG                bool
# Fuel_Type_Diesel             bool
# Fuel_Type_Petrol             bool
# Seller_Type_Individual       bool
# Transmission_Manual          bool
# dtype: object

# %%
df.corr()
# Out:
#                             Year  ...  Transmission_Manual
# Year                    1.000000  ...             0.000394
# Selling_Price           0.236141  ...            -0.367128
# Present_Price          -0.047584  ...            -0.348715
# Kms_Driven             -0.524342  ...            -0.162510
# Owner                  -0.182104  ...            -0.050316
# Fuel_Type_CNG          -0.017790  ...             0.032018
# Fuel_Type_Diesel        0.064315  ...            -0.098643
# Fuel_Type_Petrol       -0.059959  ...             0.091013
# Seller_Type_Individual -0.039896  ...             0.063240
# Transmission_Manual     0.000394  ...             1.000000
#
# [10 rows x 10 columns]

# %%
price_corr=abs(df.corr()["Selling_Price"])
price_corr.sort_values(ascending=False)
# Out:
# Selling_Price             1.000000
# Present_Price             0.878983
# Fuel_Type_Diesel          0.552339
# Seller_Type_Individual    0.550724
# Fuel_Type_Petrol          0.540571
# Transmission_Manual       0.367128
# Year                      0.236141
# Owner                     0.088344
# Kms_Driven                0.029187
# Fuel_Type_CNG             0.025164
# Name: Selling_Price, dtype: float64

# %%
df['Year']=2026-df['Year']

# %%
X=df.drop("Selling_Price",axis=1)
y=df["Selling_Price"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)
model=LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
loss=mean_squared_error(y_test,y_pred)
print("MSE:",loss)
r2_sc=r2_score(y_test,y_pred)
print("R2 Score:",r2_sc)
# Out:
# MSE: 2.7506892621405212
# R2 Score: 0.8502332355855177

# %%
for i in range(len(X.columns)):
    print(X.columns[i],model.coef_[i])
# Out:
# Year -0.40641122506490085
# Present_Price 0.4288029813074983
# Kms_Driven -5.923169033417164e-06
# Owner -0.8490097266245104
# Fuel_Type_CNG -1.187888799914448
# Fuel_Type_Diesel 1.6726740495971317
# Fuel_Type_Petrol -0.4847852496826838
# Seller_Type_Individual -1.0747734712456662
# Transmission_Manual -1.5089797453609077
